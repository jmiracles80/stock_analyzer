# %%
import gym

from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common.vec_env import DummyVecEnv
from stable_baselines import PPO2

env = gym.make('CartPole-v1')
# Optional: PPO2 requires a vectorized environment to run
# the env is now wrapped automatically when passing it to the constructor
# env = DummyVecEnv([lambda: env])

model = PPO2(MlpPolicy, env, verbose=1)
model.learn(total_timesteps=10000)

obs = env.reset()
for i in range(1000):
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render(mode='human')

env.close()
# Out:
# /Users/jmiracles80/miniconda3/envs/py37/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/jmiracles80/miniconda3/envs/py37/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/jmiracles80/miniconda3/envs/py37/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/jmiracles80/miniconda3/envs/py37/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/jmiracles80/miniconda3/envs/py37/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/jmiracles80/miniconda3/envs/py37/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /Users/jmiracles80/miniconda3/envs/py37/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/jmiracles80/miniconda3/envs/py37/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/jmiracles80/miniconda3/envs/py37/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/jmiracles80/miniconda3/envs/py37/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/jmiracles80/miniconda3/envs/py37/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/jmiracles80/miniconda3/envs/py37/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Wrapping the env in a DummyVecEnv.
# WARNING:tensorflow:From /Users/jmiracles80/miniconda3/envs/py37/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /Users/jmiracles80/miniconda3/envs/py37/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /Users/jmiracles80/miniconda3/envs/py37/lib/python3.7/site-packages/stable_baselines/common/policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /Users/jmiracles80/miniconda3/envs/py37/lib/python3.7/site-packages/stable_baselines/common/input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /Users/jmiracles80/miniconda3/envs/py37/lib/python3.7/site-packages/stable_baselines/common/policies.py:561: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f90689c0f90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f90689c0f90>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f90689c0f90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f90689c0f90>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:From /Users/jmiracles80/miniconda3/envs/py37/lib/python3.7/site-packages/stable_baselines/common/tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f9068bdaa90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f9068bdaa90>>: AttributeError: module 'gast' has no attribute 'Index'
# /Users/jmiracles80/miniconda3/envs/py37/lib/python3.7/site-packages/stable_baselines/__init__.py:33: UserWarning: stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation.
#   "stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation."
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f9068bdaa90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f9068bdaa90>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:From /Users/jmiracles80/miniconda3/envs/py37/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:190: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /Users/jmiracles80/miniconda3/envs/py37/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /Users/jmiracles80/miniconda3/envs/py37/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:206: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /Users/jmiracles80/miniconda3/envs/py37/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:242: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# ---------------------------------------
# | approxkl           | 4.564076e-06   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.026         |
# | fps                | 388            |
# | n_updates          | 1              |
# | policy_entropy     | 0.6931416      |
# | policy_loss        | -0.00012018846 |
# | serial_timesteps   | 128            |
# | time_elapsed       | 9.78e-06       |
# | total_timesteps    | 128            |
# | value_loss         | 63.103985      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 4.2790757e-06  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.00559       |
# | fps                | 1795           |
# | n_updates          | 2              |
# | policy_entropy     | 0.69313717     |
# | policy_loss        | -2.7004862e-05 |
# | serial_timesteps   | 256            |
# | time_elapsed       | 0.331          |
# | total_timesteps    | 256            |
# | value_loss         | 58.84881       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 7.948976e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0236       |
# | fps                | 1518          |
# | n_updates          | 3             |
# | policy_entropy     | 0.6929089     |
# | policy_loss        | -0.0017632061 |
# | serial_timesteps   | 384           |
# | time_elapsed       | 0.403         |
# | total_timesteps    | 384           |
# | value_loss         | 36.956356     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00018757966 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0291       |
# | fps                | 1741          |
# | n_updates          | 4             |
# | policy_entropy     | 0.6916082     |
# | policy_loss        | -0.001974599  |
# | serial_timesteps   | 512           |
# | time_elapsed       | 0.488         |
# | total_timesteps    | 512           |
# | value_loss         | 34.69759      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00015011929 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00448      |
# | fps                | 2026          |
# | n_updates          | 5             |
# | policy_entropy     | 0.6902232     |
# | policy_loss        | -0.0028334078 |
# | serial_timesteps   | 640           |
# | time_elapsed       | 0.563         |
# | total_timesteps    | 640           |
# | value_loss         | 45.284576     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00036477484 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00576      |
# | fps                | 2039          |
# | n_updates          | 6             |
# | policy_entropy     | 0.6862112     |
# | policy_loss        | -0.0058112387 |
# | serial_timesteps   | 768           |
# | time_elapsed       | 0.626         |
# | total_timesteps    | 768           |
# | value_loss         | 32.27198      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00017719534 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00332       |
# | fps                | 1981          |
# | n_updates          | 7             |
# | policy_entropy     | 0.68513197    |
# | policy_loss        | -0.0024207777 |
# | serial_timesteps   | 896           |
# | time_elapsed       | 0.69          |
# | total_timesteps    | 896           |
# | value_loss         | 48.954796     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00012013897 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0179       |
# | fps                | 1673          |
# | n_updates          | 8             |
# | policy_entropy     | 0.6777495     |
# | policy_loss        | -0.0020926176 |
# | serial_timesteps   | 1024          |
# | time_elapsed       | 0.755         |
# | total_timesteps    | 1024          |
# | value_loss         | 59.84291      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00019516595 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0134        |
# | fps                | 1755          |
# | n_updates          | 9             |
# | policy_entropy     | 0.67520535    |
# | policy_loss        | -0.0035893333 |
# | serial_timesteps   | 1152          |
# | time_elapsed       | 0.833         |
# | total_timesteps    | 1152          |
# | value_loss         | 42.513184     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00011927279 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0182       |
# | fps                | 1623          |
# | n_updates          | 10            |
# | policy_entropy     | 0.6701864     |
# | policy_loss        | 0.00024372374 |
# | serial_timesteps   | 1280          |
# | time_elapsed       | 0.906         |
# | total_timesteps    | 1280          |
# | value_loss         | 80.055466     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00012018462  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0333         |
# | fps                | 1833           |
# | n_updates          | 11             |
# | policy_entropy     | 0.65634376     |
# | policy_loss        | -0.00038752612 |
# | serial_timesteps   | 1408           |
# | time_elapsed       | 0.986          |
# | total_timesteps    | 1408           |
# | value_loss         | 35.718597      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 9.221027e-06  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0266       |
# | fps                | 1997          |
# | n_updates          | 12            |
# | policy_entropy     | 0.6711732     |
# | policy_loss        | 0.00011093193 |
# | serial_timesteps   | 1536          |
# | time_elapsed       | 1.06          |
# | total_timesteps    | 1536          |
# | value_loss         | 41.102627     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 7.7484874e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0173        |
# | fps                | 2059          |
# | n_updates          | 13            |
# | policy_entropy     | 0.6650621     |
# | policy_loss        | -0.001350345  |
# | serial_timesteps   | 1664          |
# | time_elapsed       | 1.12          |
# | total_timesteps    | 1664          |
# | value_loss         | 69.89537      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0006342756  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.000386     |
# | fps                | 2074          |
# | n_updates          | 14            |
# | policy_entropy     | 0.6546384     |
# | policy_loss        | -0.0050536296 |
# | serial_timesteps   | 1792          |
# | time_elapsed       | 1.18          |
# | total_timesteps    | 1792          |
# | value_loss         | 33.808346     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0007415209  |
# | clipfrac           | 0.001953125   |
# | explained_variance | 0.0483        |
# | fps                | 2097          |
# | n_updates          | 15            |
# | policy_entropy     | 0.6379106     |
# | policy_loss        | -0.0043271063 |
# | serial_timesteps   | 1920          |
# | time_elapsed       | 1.25          |
# | total_timesteps    | 1920          |
# | value_loss         | 68.01423      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0003688643  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0787       |
# | fps                | 2153          |
# | n_updates          | 16            |
# | policy_entropy     | 0.6368558     |
# | policy_loss        | -0.0032443507 |
# | serial_timesteps   | 2048          |
# | time_elapsed       | 1.31          |
# | total_timesteps    | 2048          |
# | value_loss         | 83.94029      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.3550684e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0326        |
# | fps                | 2108          |
# | n_updates          | 17            |
# | policy_entropy     | 0.6343892     |
# | policy_loss        | 0.00052268826 |
# | serial_timesteps   | 2176          |
# | time_elapsed       | 1.37          |
# | total_timesteps    | 2176          |
# | value_loss         | 62.8526       |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00043258205 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0397        |
# | fps                | 2136          |
# | n_updates          | 18            |
# | policy_entropy     | 0.6353873     |
# | policy_loss        | -0.0054771174 |
# | serial_timesteps   | 2304          |
# | time_elapsed       | 1.43          |
# | total_timesteps    | 2304          |
# | value_loss         | 71.48569      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00016781784 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.011         |
# | fps                | 2139          |
# | n_updates          | 19            |
# | policy_entropy     | 0.6232202     |
# | policy_loss        | -0.0014690807 |
# | serial_timesteps   | 2432          |
# | time_elapsed       | 1.49          |
# | total_timesteps    | 2432          |
# | value_loss         | 59.957413     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 8.312497e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.00512       |
# | fps                | 2084           |
# | n_updates          | 20             |
# | policy_entropy     | 0.6274113      |
# | policy_loss        | -0.00017415348 |
# | serial_timesteps   | 2560           |
# | time_elapsed       | 1.55           |
# | total_timesteps    | 2560           |
# | value_loss         | 78.390175      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0001069967  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00527      |
# | fps                | 1994          |
# | n_updates          | 21            |
# | policy_entropy     | 0.5992462     |
# | policy_loss        | -0.0021399418 |
# | serial_timesteps   | 2688          |
# | time_elapsed       | 1.61          |
# | total_timesteps    | 2688          |
# | value_loss         | 44.443        |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00012973219 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00429      |
# | fps                | 1987          |
# | n_updates          | 22            |
# | policy_entropy     | 0.59973216    |
# | policy_loss        | -0.0010519141 |
# | serial_timesteps   | 2816          |
# | time_elapsed       | 1.68          |
# | total_timesteps    | 2816          |
# | value_loss         | 59.116436     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00016070888 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0486        |
# | fps                | 1796          |
# | n_updates          | 23            |
# | policy_entropy     | 0.63032275    |
# | policy_loss        | -0.0032998053 |
# | serial_timesteps   | 2944          |
# | time_elapsed       | 1.74          |
# | total_timesteps    | 2944          |
# | value_loss         | 75.01153      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00010778317 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00522       |
# | fps                | 1758          |
# | n_updates          | 24            |
# | policy_entropy     | 0.6022338     |
# | policy_loss        | -0.0007632698 |
# | serial_timesteps   | 3072          |
# | time_elapsed       | 1.82          |
# | total_timesteps    | 3072          |
# | value_loss         | 56.982246     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 8.867222e-05 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.0809       |
# | fps                | 1785         |
# | n_updates          | 25           |
# | policy_entropy     | 0.6244426    |
# | policy_loss        | 0.001469898  |
# | serial_timesteps   | 3200         |
# | time_elapsed       | 1.89         |
# | total_timesteps    | 3200         |
# | value_loss         | 68.6647      |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00034426048 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.055         |
# | fps                | 2086          |
# | n_updates          | 26            |
# | policy_entropy     | 0.6231585     |
# | policy_loss        | -0.0015797579 |
# | serial_timesteps   | 3328          |
# | time_elapsed       | 1.96          |
# | total_timesteps    | 3328          |
# | value_loss         | 94.01135      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.6270623e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.089         |
# | fps                | 2121          |
# | n_updates          | 27            |
# | policy_entropy     | 0.5921059     |
# | policy_loss        | -0.0008190882 |
# | serial_timesteps   | 3456          |
# | time_elapsed       | 2.02          |
# | total_timesteps    | 3456          |
# | value_loss         | 72.30139      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00010894562 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0485        |
# | fps                | 2119          |
# | n_updates          | 28            |
# | policy_entropy     | 0.6139509     |
# | policy_loss        | -0.0016228368 |
# | serial_timesteps   | 3584          |
# | time_elapsed       | 2.09          |
# | total_timesteps    | 3584          |
# | value_loss         | 71.54708      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00013550148 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.117         |
# | fps                | 2143          |
# | n_updates          | 29            |
# | policy_entropy     | 0.60274625    |
# | policy_loss        | -0.0035620457 |
# | serial_timesteps   | 3712          |
# | time_elapsed       | 2.15          |
# | total_timesteps    | 3712          |
# | value_loss         | 50.450165     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0002022898  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.267         |
# | fps                | 2144          |
# | n_updates          | 30            |
# | policy_entropy     | 0.6268118     |
# | policy_loss        | -0.0029280432 |
# | serial_timesteps   | 3840          |
# | time_elapsed       | 2.21          |
# | total_timesteps    | 3840          |
# | value_loss         | 93.68297      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0009912227 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.187        |
# | fps                | 2102         |
# | n_updates          | 31           |
# | policy_entropy     | 0.62685007   |
# | policy_loss        | 0.0057983864 |
# | serial_timesteps   | 3968         |
# | time_elapsed       | 2.27         |
# | total_timesteps    | 3968         |
# | value_loss         | 72.43536     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0017827337  |
# | clipfrac           | 0.00390625    |
# | explained_variance | 0.0431        |
# | fps                | 2076          |
# | n_updates          | 32            |
# | policy_entropy     | 0.5825468     |
# | policy_loss        | -0.0010107834 |
# | serial_timesteps   | 4096          |
# | time_elapsed       | 2.33          |
# | total_timesteps    | 4096          |
# | value_loss         | 69.68162      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 8.795306e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0423         |
# | fps                | 2132           |
# | n_updates          | 33             |
# | policy_entropy     | 0.6074355      |
# | policy_loss        | 1.05770305e-05 |
# | serial_timesteps   | 4224           |
# | time_elapsed       | 2.39           |
# | total_timesteps    | 4224           |
# | value_loss         | 68.36          |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0008482589  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.276         |
# | fps                | 2148          |
# | n_updates          | 34            |
# | policy_entropy     | 0.61371577    |
# | policy_loss        | 0.00043538376 |
# | serial_timesteps   | 4352          |
# | time_elapsed       | 2.45          |
# | total_timesteps    | 4352          |
# | value_loss         | 91.76946      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 6.0134334e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0575        |
# | fps                | 1906          |
# | n_updates          | 35            |
# | policy_entropy     | 0.6118272     |
# | policy_loss        | 0.0010809193  |
# | serial_timesteps   | 4480          |
# | time_elapsed       | 2.51          |
# | total_timesteps    | 4480          |
# | value_loss         | 81.09347      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.963914e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0067        |
# | fps                | 2169          |
# | n_updates          | 36            |
# | policy_entropy     | 0.57957625    |
# | policy_loss        | -0.0020123364 |
# | serial_timesteps   | 4608          |
# | time_elapsed       | 2.58          |
# | total_timesteps    | 4608          |
# | value_loss         | 57.250393     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 3.22483e-05  |
# | clipfrac           | 0.0          |
# | explained_variance | -0.0613      |
# | fps                | 2098         |
# | n_updates          | 37           |
# | policy_entropy     | 0.6065022    |
# | policy_loss        | 0.0005617638 |
# | serial_timesteps   | 4736         |
# | time_elapsed       | 2.64         |
# | total_timesteps    | 4736         |
# | value_loss         | 92.353546    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 4.6988298e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00286      |
# | fps                | 1726          |
# | n_updates          | 38            |
# | policy_entropy     | 0.59327954    |
# | policy_loss        | 0.00052401866 |
# | serial_timesteps   | 4864          |
# | time_elapsed       | 2.7           |
# | total_timesteps    | 4864          |
# | value_loss         | 65.3594       |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00029054648 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0894        |
# | fps                | 1660          |
# | n_updates          | 39            |
# | policy_entropy     | 0.6062308     |
# | policy_loss        | 0.00018752326 |
# | serial_timesteps   | 4992          |
# | time_elapsed       | 2.78          |
# | total_timesteps    | 4992          |
# | value_loss         | 62.15212      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.5107677e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.353         |
# | fps                | 2055          |
# | n_updates          | 40            |
# | policy_entropy     | 0.5830931     |
# | policy_loss        | -3.556488e-06 |
# | serial_timesteps   | 5120          |
# | time_elapsed       | 2.85          |
# | total_timesteps    | 5120          |
# | value_loss         | 63.523293     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 6.9632726e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0356        |
# | fps                | 2003          |
# | n_updates          | 41            |
# | policy_entropy     | 0.60582227    |
# | policy_loss        | 0.0018558289  |
# | serial_timesteps   | 5248          |
# | time_elapsed       | 2.92          |
# | total_timesteps    | 5248          |
# | value_loss         | 62.41727      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.3481496e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.141         |
# | fps                | 2001           |
# | n_updates          | 42             |
# | policy_entropy     | 0.57786334     |
# | policy_loss        | -0.00080983853 |
# | serial_timesteps   | 5376           |
# | time_elapsed       | 2.98           |
# | total_timesteps    | 5376           |
# | value_loss         | 70.528404      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 9.3563256e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.123        |
# | fps                | 2050          |
# | n_updates          | 43            |
# | policy_entropy     | 0.5860796     |
# | policy_loss        | -0.0031096116 |
# | serial_timesteps   | 5504          |
# | time_elapsed       | 3.05          |
# | total_timesteps    | 5504          |
# | value_loss         | 70.24847      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.000122797  |
# | clipfrac           | 0.0          |
# | explained_variance | 0.134        |
# | fps                | 2047         |
# | n_updates          | 44           |
# | policy_entropy     | 0.5998654    |
# | policy_loss        | 0.0017691767 |
# | serial_timesteps   | 5632         |
# | time_elapsed       | 3.11         |
# | total_timesteps    | 5632         |
# | value_loss         | 66.49573     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 8.610508e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0101       |
# | fps                | 2038          |
# | n_updates          | 45            |
# | policy_entropy     | 0.59781307    |
# | policy_loss        | -0.0013004472 |
# | serial_timesteps   | 5760          |
# | time_elapsed       | 3.17          |
# | total_timesteps    | 5760          |
# | value_loss         | 85.87344      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0020918665 |
# | clipfrac           | 0.029296875  |
# | explained_variance | 0.0811       |
# | fps                | 2050         |
# | n_updates          | 46           |
# | policy_entropy     | 0.61674136   |
# | policy_loss        | 0.027032377  |
# | serial_timesteps   | 5888         |
# | time_elapsed       | 3.24         |
# | total_timesteps    | 5888         |
# | value_loss         | 72.66819     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00021642944 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.18          |
# | fps                | 2094          |
# | n_updates          | 47            |
# | policy_entropy     | 0.6100578     |
# | policy_loss        | 0.00022699416 |
# | serial_timesteps   | 6016          |
# | time_elapsed       | 3.3           |
# | total_timesteps    | 6016          |
# | value_loss         | 60.035767     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.4883215e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0504        |
# | fps                | 2013          |
# | n_updates          | 48            |
# | policy_entropy     | 0.60751873    |
# | policy_loss        | 0.00010481151 |
# | serial_timesteps   | 6144          |
# | time_elapsed       | 3.36          |
# | total_timesteps    | 6144          |
# | value_loss         | 58.27073      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 1.899939e-05 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.199        |
# | fps                | 2002         |
# | n_updates          | 49           |
# | policy_entropy     | 0.60846746   |
# | policy_loss        | 0.0001249077 |
# | serial_timesteps   | 6272         |
# | time_elapsed       | 3.43         |
# | total_timesteps    | 6272         |
# | value_loss         | 81.452034    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00035164368 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.136        |
# | fps                | 2016          |
# | n_updates          | 50            |
# | policy_entropy     | 0.5890899     |
# | policy_loss        | 0.00016163441 |
# | serial_timesteps   | 6400          |
# | time_elapsed       | 3.49          |
# | total_timesteps    | 6400          |
# | value_loss         | 51.176582     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.1522643e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0384        |
# | fps                | 2048          |
# | n_updates          | 51            |
# | policy_entropy     | 0.60649526    |
# | policy_loss        | -0.0013002728 |
# | serial_timesteps   | 6528          |
# | time_elapsed       | 3.55          |
# | total_timesteps    | 6528          |
# | value_loss         | 68.50201      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00027985976 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0635        |
# | fps                | 2104          |
# | n_updates          | 52            |
# | policy_entropy     | 0.59366655    |
# | policy_loss        | -0.0038299393 |
# | serial_timesteps   | 6656          |
# | time_elapsed       | 3.62          |
# | total_timesteps    | 6656          |
# | value_loss         | 62.825985     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00060007046 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0111       |
# | fps                | 2095          |
# | n_updates          | 53            |
# | policy_entropy     | 0.5272583     |
# | policy_loss        | -0.004190708  |
# | serial_timesteps   | 6784          |
# | time_elapsed       | 3.68          |
# | total_timesteps    | 6784          |
# | value_loss         | 41.8853       |
# --------------------------------------
# --------------------------------------
# | approxkl           | 7.720489e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0343       |
# | fps                | 2160          |
# | n_updates          | 54            |
# | policy_entropy     | 0.5717096     |
# | policy_loss        | -0.0010501653 |
# | serial_timesteps   | 6912          |
# | time_elapsed       | 3.74          |
# | total_timesteps    | 6912          |
# | value_loss         | 61.753757     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 7.714559e-05 |
# | clipfrac           | 0.0          |
# | explained_variance | -0.023       |
# | fps                | 2151         |
# | n_updates          | 55           |
# | policy_entropy     | 0.5784656    |
# | policy_loss        | 0.001496589  |
# | serial_timesteps   | 7040         |
# | time_elapsed       | 3.8          |
# | total_timesteps    | 7040         |
# | value_loss         | 80.206085    |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 2.7340557e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.187          |
# | fps                | 2136           |
# | n_updates          | 56             |
# | policy_entropy     | 0.58075696     |
# | policy_loss        | -1.1983211e-06 |
# | serial_timesteps   | 7168           |
# | time_elapsed       | 3.86           |
# | total_timesteps    | 7168           |
# | value_loss         | 52.814793      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00024382927 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.319        |
# | fps                | 2158          |
# | n_updates          | 57            |
# | policy_entropy     | 0.62130094    |
# | policy_loss        | -0.0005394154 |
# | serial_timesteps   | 7296          |
# | time_elapsed       | 3.92          |
# | total_timesteps    | 7296          |
# | value_loss         | 84.28207      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.000944436  |
# | clipfrac           | 0.0078125    |
# | explained_variance | 0.114        |
# | fps                | 2153         |
# | n_updates          | 58           |
# | policy_entropy     | 0.5841406    |
# | policy_loss        | 0.0063602794 |
# | serial_timesteps   | 7424         |
# | time_elapsed       | 3.98         |
# | total_timesteps    | 7424         |
# | value_loss         | 64.39358     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 3.2415566e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0787        |
# | fps                | 2152          |
# | n_updates          | 59            |
# | policy_entropy     | 0.5938997     |
# | policy_loss        | 0.00011214247 |
# | serial_timesteps   | 7552          |
# | time_elapsed       | 4.04          |
# | total_timesteps    | 7552          |
# | value_loss         | 73.55566      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.1487538e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.185         |
# | fps                | 2140          |
# | n_updates          | 60            |
# | policy_entropy     | 0.6159713     |
# | policy_loss        | 6.329006e-05  |
# | serial_timesteps   | 7680          |
# | time_elapsed       | 4.1           |
# | total_timesteps    | 7680          |
# | value_loss         | 59.71802      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.7662869e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0534       |
# | fps                | 2163          |
# | n_updates          | 61            |
# | policy_entropy     | 0.5767072     |
# | policy_loss        | -0.0008297252 |
# | serial_timesteps   | 7808          |
# | time_elapsed       | 4.16          |
# | total_timesteps    | 7808          |
# | value_loss         | 58.80226      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 4.774258e-05 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.00149      |
# | fps                | 2173         |
# | n_updates          | 62           |
# | policy_entropy     | 0.5756893    |
# | policy_loss        | 0.0017012273 |
# | serial_timesteps   | 7936         |
# | time_elapsed       | 4.22         |
# | total_timesteps    | 7936         |
# | value_loss         | 59.31973     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 4.3362714e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0789        |
# | fps                | 2092          |
# | n_updates          | 63            |
# | policy_entropy     | 0.58530337    |
# | policy_loss        | -0.0019749845 |
# | serial_timesteps   | 8064          |
# | time_elapsed       | 4.28          |
# | total_timesteps    | 8064          |
# | value_loss         | 52.911434     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.9201866e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.137        |
# | fps                | 2154          |
# | n_updates          | 64            |
# | policy_entropy     | 0.590914      |
# | policy_loss        | 0.00033084222 |
# | serial_timesteps   | 8192          |
# | time_elapsed       | 4.34          |
# | total_timesteps    | 8192          |
# | value_loss         | 76.09582      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00018513642 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0665        |
# | fps                | 2159          |
# | n_updates          | 65            |
# | policy_entropy     | 0.5938748     |
# | policy_loss        | -0.0032927275 |
# | serial_timesteps   | 8320          |
# | time_elapsed       | 4.4           |
# | total_timesteps    | 8320          |
# | value_loss         | 53.96561      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00027315074 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0796        |
# | fps                | 2162          |
# | n_updates          | 66            |
# | policy_entropy     | 0.612782      |
# | policy_loss        | 0.0023691994  |
# | serial_timesteps   | 8448          |
# | time_elapsed       | 4.46          |
# | total_timesteps    | 8448          |
# | value_loss         | 53.91187      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 3.0425194e-06  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.189          |
# | fps                | 2181           |
# | n_updates          | 67             |
# | policy_entropy     | 0.60197353     |
# | policy_loss        | -1.4389399e-05 |
# | serial_timesteps   | 8576           |
# | time_elapsed       | 4.52           |
# | total_timesteps    | 8576           |
# | value_loss         | 71.99155       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00011980037 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.176         |
# | fps                | 2212          |
# | n_updates          | 68            |
# | policy_entropy     | 0.5980887     |
# | policy_loss        | -0.0012400838 |
# | serial_timesteps   | 8704          |
# | time_elapsed       | 4.58          |
# | total_timesteps    | 8704          |
# | value_loss         | 58.076473     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.0439102e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0424       |
# | fps                | 2075          |
# | n_updates          | 69            |
# | policy_entropy     | 0.5611654     |
# | policy_loss        | -0.0015704691 |
# | serial_timesteps   | 8832          |
# | time_elapsed       | 4.64          |
# | total_timesteps    | 8832          |
# | value_loss         | 56.638298     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.835951e-06  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0102        |
# | fps                | 2144          |
# | n_updates          | 70            |
# | policy_entropy     | 0.5862364     |
# | policy_loss        | 0.00024783378 |
# | serial_timesteps   | 8960          |
# | time_elapsed       | 4.71          |
# | total_timesteps    | 8960          |
# | value_loss         | 54.88217      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 5.3906544e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.156          |
# | fps                | 2100           |
# | n_updates          | 71             |
# | policy_entropy     | 0.58358216     |
# | policy_loss        | -0.00063838356 |
# | serial_timesteps   | 9088           |
# | time_elapsed       | 4.77           |
# | total_timesteps    | 9088           |
# | value_loss         | 70.52199       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0008327754  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.15          |
# | fps                | 2155          |
# | n_updates          | 72            |
# | policy_entropy     | 0.5647229     |
# | policy_loss        | -0.0071792575 |
# | serial_timesteps   | 9216          |
# | time_elapsed       | 4.83          |
# | total_timesteps    | 9216          |
# | value_loss         | 60.343334     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.573686e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0123        |
# | fps                | 2171          |
# | n_updates          | 73            |
# | policy_entropy     | 0.58412385    |
# | policy_loss        | -0.0014774669 |
# | serial_timesteps   | 9344          |
# | time_elapsed       | 4.89          |
# | total_timesteps    | 9344          |
# | value_loss         | 71.53386      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.0237533e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.055          |
# | fps                | 2112           |
# | n_updates          | 74             |
# | policy_entropy     | 0.6024994      |
# | policy_loss        | -0.00022478786 |
# | serial_timesteps   | 9472           |
# | time_elapsed       | 4.95           |
# | total_timesteps    | 9472           |
# | value_loss         | 58.25498       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 9.439879e-06  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0638        |
# | fps                | 2147          |
# | n_updates          | 75            |
# | policy_entropy     | 0.59683585    |
# | policy_loss        | 0.00012393005 |
# | serial_timesteps   | 9600          |
# | time_elapsed       | 5.01          |
# | total_timesteps    | 9600          |
# | value_loss         | 69.61755      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 7.597188e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.199         |
# | fps                | 2078          |
# | n_updates          | 76            |
# | policy_entropy     | 0.6057168     |
# | policy_loss        | 0.00076768524 |
# | serial_timesteps   | 9728          |
# | time_elapsed       | 5.07          |
# | total_timesteps    | 9728          |
# | value_loss         | 50.55427      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.6155603e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0406        |
# | fps                | 2143          |
# | n_updates          | 77            |
# | policy_entropy     | 0.5699331     |
# | policy_loss        | -9.14589e-05  |
# | serial_timesteps   | 9856          |
# | time_elapsed       | 5.13          |
# | total_timesteps    | 9856          |
# | value_loss         | 52.17054      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 6.9072235e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0623       |
# | fps                | 2168          |
# | n_updates          | 78            |
# | policy_entropy     | 0.60230404    |
# | policy_loss        | -0.0003142247 |
# | serial_timesteps   | 9984          |
# | time_elapsed       | 5.19          |
# | total_timesteps    | 9984          |
# | value_loss         | 68.60681      |
# --------------------------------------
# /Users/jmiracles80/miniconda3/envs/py37/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: You are calling 'step()' even though this environment has already returned done = True. You should always call 'reset()' once you receive 'done = True' -- any further steps are undefined behavior.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
