# %%
! pip install stable-baselines -q

# %%
import gym
import pandas as pd
import numpy as np
from gym import spaces
from sklearn import preprocessing
import datetime
from datetime import date
import yfinance as yf

# %%
date_labels = np.array([datetime.utcfromtimestamp(x).strftime('%Y-%m-%d %H:%M') for x in self.df['Timestamp'].values[step_range]])

# %%
end_time = date.today()
start_time = end_time - datetime.timedelta(days=1000)
print(start_time)
print(end_time)
symbol = 'SHAK'

#df.head()

df = yf.download(symbol, period='9mo', interval="1h")
#df = df.sort_values('Date')
print(len(df))
df.head(136)
# Out:
# 2018-09-06
# 2021-06-02
# [*********************100%***********************]  1 of 1 completed
# 1303
#                                 Open       High        Low      Close  \
# 2020-09-03 09:30:00-04:00  68.860001  69.129997  67.419998  67.589996
# 2020-09-03 10:30:00-04:00  67.519997  67.747803  66.275002  67.199997
# 2020-09-03 11:30:00-04:00  67.139999  67.660004  66.849998  67.320000
# 2020-09-03 12:30:00-04:00  67.260002  67.720001  66.930000  67.555000
# 2020-09-03 13:30:00-04:00  67.580002  67.580002  66.849998  67.285004
# ...                              ...        ...        ...        ...
# 2020-09-30 14:30:00-04:00  65.139999  65.139999  63.490002  64.010002
# 2020-09-30 15:30:00-04:00  63.889999  64.699997  63.759998  64.480003
# 2020-10-01 09:30:00-04:00  65.019997  65.230003  64.080002  64.879997
# 2020-10-01 10:30:00-04:00  64.849998  65.339996  64.665001  65.080002
# 2020-10-01 11:30:00-04:00  65.089996  65.199997  64.485001  64.629997
#
#                            Adj Close  Volume
# 2020-09-03 09:30:00-04:00  67.589996  217452
# 2020-09-03 10:30:00-04:00  67.199997  224374
# 2020-09-03 11:30:00-04:00  67.320000  170506
# 2020-09-03 12:30:00-04:00  67.555000  141642
# 2020-09-03 13:30:00-04:00  67.285004   92900
# ...                              ...     ...
# 2020-09-30 14:30:00-04:00  64.010002  198824
# 2020-09-30 15:30:00-04:00  64.480003  253587
# 2020-10-01 09:30:00-04:00  64.879997  257051
# 2020-10-01 10:30:00-04:00  65.080002  119583
# 2020-10-01 11:30:00-04:00  64.629997  112598
#
# [136 rows x 6 columns]

# %%
slice_point = int(len(df) - 100000)
train_df = df[:slice_point]

test_df = df[slice_point:]

# %%
len(df)
# Out:
# 1303

# %%
lookback_window_size=50
MAX_TRADING_SESSION = 1000
steps_left = np.random.randint(1, MAX_TRADING_SESSION)
frame_start = np.random.randint(lookback_window_size, len(df) - steps_left)

# %%
import gym
import json
import datetime as dt
from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common.vec_env import DummyVecEnv
from stable_baselines import PPO2
#from env.BitcoinTradingEnv import BitcoinTradingEnv
import pandas as pd
from tensorflow.python.compiler.tensorrt import trt_convert as trt

# df = yf.download(symbol, start=start_time.strftime("%Y-%m-%d"), end= end_time.strftime("%Y-%m-%d"), interval="1d")
# df = df.sort_values('Date')
# The algorithms require a vectorized environment to run

train_env = DummyVecEnv([lambda: BitcoinTradingEnv(df, 
                         commission=0, serial=False)])
test_env = DummyVecEnv([lambda: BitcoinTradingEnv(test_df, 
                        commission=0, serial=True)])


model = PPO2(MlpPolicy,
             train_env,
             verbose=1, 
             tensorboard_log="./tensorboard/")
model.learn(total_timesteps=50000)
# Out:
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7ff980b0d6d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7ff980b0d6d0>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7ff980b0d6d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7ff980b0d6d0>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7ff982ca9b50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7ff982ca9b50>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7ff982ca9b50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7ff982ca9b50>>: AttributeError: module 'gast' has no attribute 'Index'
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 238      |
# | n_updates          | 1        |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 128      |
# | time_elapsed       | 2.1e-05  |
# | total_timesteps    | 128      |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 903      |
# | n_updates          | 2        |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 256      |
# | time_elapsed       | 0.539    |
# | total_timesteps    | 256      |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 843      |
# | n_updates          | 3        |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 384      |
# | time_elapsed       | 0.682    |
# | total_timesteps    | 384      |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 787      |
# | n_updates          | 4        |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 512      |
# | time_elapsed       | 0.835    |
# | total_timesteps    | 512      |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 730      |
# | n_updates          | 5        |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 640      |
# | time_elapsed       | 0.999    |
# | total_timesteps    | 640      |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 944      |
# | n_updates          | 6        |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 768      |
# | time_elapsed       | 1.17     |
# | total_timesteps    | 768      |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 977      |
# | n_updates          | 7        |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 896      |
# | time_elapsed       | 1.31     |
# | total_timesteps    | 896      |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 911      |
# | n_updates          | 8        |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 1024     |
# | time_elapsed       | 1.44     |
# | total_timesteps    | 1024     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 863      |
# | n_updates          | 9        |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 1152     |
# | time_elapsed       | 1.59     |
# | total_timesteps    | 1152     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 988      |
# | n_updates          | 10       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 1280     |
# | time_elapsed       | 1.73     |
# | total_timesteps    | 1280     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 994      |
# | n_updates          | 11       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 1408     |
# | time_elapsed       | 1.86     |
# | total_timesteps    | 1408     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 989      |
# | n_updates          | 12       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 1536     |
# | time_elapsed       | 1.99     |
# | total_timesteps    | 1536     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 1014     |
# | n_updates          | 13       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 1664     |
# | time_elapsed       | 2.12     |
# | total_timesteps    | 1664     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 968      |
# | n_updates          | 14       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 1792     |
# | time_elapsed       | 2.25     |
# | total_timesteps    | 1792     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 692      |
# | n_updates          | 15       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 1920     |
# | time_elapsed       | 2.39     |
# | total_timesteps    | 1920     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 537      |
# | n_updates          | 16       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 2048     |
# | time_elapsed       | 2.57     |
# | total_timesteps    | 2048     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 801      |
# | n_updates          | 17       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 2176     |
# | time_elapsed       | 2.81     |
# | total_timesteps    | 2176     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 912      |
# | n_updates          | 18       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 2304     |
# | time_elapsed       | 2.97     |
# | total_timesteps    | 2304     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 995      |
# | n_updates          | 19       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 2432     |
# | time_elapsed       | 3.11     |
# | total_timesteps    | 2432     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 1001     |
# | n_updates          | 20       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 2560     |
# | time_elapsed       | 3.24     |
# | total_timesteps    | 2560     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 949      |
# | n_updates          | 21       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 2688     |
# | time_elapsed       | 3.37     |
# | total_timesteps    | 2688     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 910      |
# | n_updates          | 22       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 2816     |
# | time_elapsed       | 3.51     |
# | total_timesteps    | 2816     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 850      |
# | n_updates          | 23       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 2944     |
# | time_elapsed       | 3.65     |
# | total_timesteps    | 2944     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 866      |
# | n_updates          | 24       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 3072     |
# | time_elapsed       | 3.8      |
# | total_timesteps    | 3072     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 906      |
# | n_updates          | 25       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 3200     |
# | time_elapsed       | 3.95     |
# | total_timesteps    | 3200     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 898      |
# | n_updates          | 26       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 3328     |
# | time_elapsed       | 4.09     |
# | total_timesteps    | 3328     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 920      |
# | n_updates          | 27       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 3456     |
# | time_elapsed       | 4.23     |
# | total_timesteps    | 3456     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 898      |
# | n_updates          | 28       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 3584     |
# | time_elapsed       | 4.37     |
# | total_timesteps    | 3584     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 813      |
# | n_updates          | 29       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 3712     |
# | time_elapsed       | 4.52     |
# | total_timesteps    | 3712     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 862      |
# | n_updates          | 30       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 3840     |
# | time_elapsed       | 4.68     |
# | total_timesteps    | 3840     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 705      |
# | n_updates          | 31       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 3968     |
# | time_elapsed       | 4.83     |
# | total_timesteps    | 3968     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 729      |
# | n_updates          | 32       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 4096     |
# | time_elapsed       | 5.01     |
# | total_timesteps    | 4096     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 866      |
# | n_updates          | 33       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 4224     |
# | time_elapsed       | 5.19     |
# | total_timesteps    | 4224     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 907      |
# | n_updates          | 34       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 4352     |
# | time_elapsed       | 5.33     |
# | total_timesteps    | 4352     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 874      |
# | n_updates          | 35       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 4480     |
# | time_elapsed       | 5.48     |
# | total_timesteps    | 4480     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 868      |
# | n_updates          | 36       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 4608     |
# | time_elapsed       | 5.62     |
# | total_timesteps    | 4608     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 849      |
# | n_updates          | 37       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 4736     |
# | time_elapsed       | 5.77     |
# | total_timesteps    | 4736     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 839      |
# | n_updates          | 38       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 4864     |
# | time_elapsed       | 5.92     |
# | total_timesteps    | 4864     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 710      |
# | n_updates          | 39       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 4992     |
# | time_elapsed       | 6.08     |
# | total_timesteps    | 4992     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 866      |
# | n_updates          | 40       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 5120     |
# | time_elapsed       | 6.26     |
# | total_timesteps    | 5120     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 852      |
# | n_updates          | 41       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 5248     |
# | time_elapsed       | 6.41     |
# | total_timesteps    | 5248     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 838      |
# | n_updates          | 42       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 5376     |
# | time_elapsed       | 6.56     |
# | total_timesteps    | 5376     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 785      |
# | n_updates          | 43       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 5504     |
# | time_elapsed       | 6.71     |
# | total_timesteps    | 5504     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 769      |
# | n_updates          | 44       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 5632     |
# | time_elapsed       | 6.88     |
# | total_timesteps    | 5632     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 665      |
# | n_updates          | 45       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 5760     |
# | time_elapsed       | 7.04     |
# | total_timesteps    | 5760     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 751      |
# | n_updates          | 46       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 5888     |
# | time_elapsed       | 7.24     |
# | total_timesteps    | 5888     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 815      |
# | n_updates          | 47       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 6016     |
# | time_elapsed       | 7.41     |
# | total_timesteps    | 6016     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 796      |
# | n_updates          | 48       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 6144     |
# | time_elapsed       | 7.57     |
# | total_timesteps    | 6144     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 636      |
# | n_updates          | 49       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 6272     |
# | time_elapsed       | 7.73     |
# | total_timesteps    | 6272     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 744      |
# | n_updates          | 50       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 6400     |
# | time_elapsed       | 7.93     |
# | total_timesteps    | 6400     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 713      |
# | n_updates          | 51       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 6528     |
# | time_elapsed       | 8.1      |
# | total_timesteps    | 6528     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 793      |
# | n_updates          | 52       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 6656     |
# | time_elapsed       | 8.28     |
# | total_timesteps    | 6656     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 815      |
# | n_updates          | 53       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 6784     |
# | time_elapsed       | 8.45     |
# | total_timesteps    | 6784     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 812      |
# | n_updates          | 54       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 6912     |
# | time_elapsed       | 8.6      |
# | total_timesteps    | 6912     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 788      |
# | n_updates          | 55       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 7040     |
# | time_elapsed       | 8.76     |
# | total_timesteps    | 7040     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 813      |
# | n_updates          | 56       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 7168     |
# | time_elapsed       | 8.93     |
# | total_timesteps    | 7168     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 792      |
# | n_updates          | 57       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 7296     |
# | time_elapsed       | 9.08     |
# | total_timesteps    | 7296     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 804      |
# | n_updates          | 58       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 7424     |
# | time_elapsed       | 9.25     |
# | total_timesteps    | 7424     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 795      |
# | n_updates          | 59       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 7552     |
# | time_elapsed       | 9.41     |
# | total_timesteps    | 7552     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 807      |
# | n_updates          | 60       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 7680     |
# | time_elapsed       | 9.57     |
# | total_timesteps    | 7680     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 795      |
# | n_updates          | 61       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 7808     |
# | time_elapsed       | 9.73     |
# | total_timesteps    | 7808     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 736      |
# | n_updates          | 62       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 7936     |
# | time_elapsed       | 9.89     |
# | total_timesteps    | 7936     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 651      |
# | n_updates          | 63       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 8064     |
# | time_elapsed       | 10.1     |
# | total_timesteps    | 8064     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 716      |
# | n_updates          | 64       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 8192     |
# | time_elapsed       | 10.3     |
# | total_timesteps    | 8192     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 698      |
# | n_updates          | 65       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 8320     |
# | time_elapsed       | 10.4     |
# | total_timesteps    | 8320     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 791      |
# | n_updates          | 66       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 8448     |
# | time_elapsed       | 10.6     |
# | total_timesteps    | 8448     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 773      |
# | n_updates          | 67       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 8576     |
# | time_elapsed       | 10.8     |
# | total_timesteps    | 8576     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 771      |
# | n_updates          | 68       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 8704     |
# | time_elapsed       | 11       |
# | total_timesteps    | 8704     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 786      |
# | n_updates          | 69       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 8832     |
# | time_elapsed       | 11.1     |
# | total_timesteps    | 8832     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 777      |
# | n_updates          | 70       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 8960     |
# | time_elapsed       | 11.3     |
# | total_timesteps    | 8960     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 750      |
# | n_updates          | 71       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 9088     |
# | time_elapsed       | 11.5     |
# | total_timesteps    | 9088     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 757      |
# | n_updates          | 72       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 9216     |
# | time_elapsed       | 11.6     |
# | total_timesteps    | 9216     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 525      |
# | n_updates          | 73       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 9344     |
# | time_elapsed       | 11.8     |
# | total_timesteps    | 9344     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 717      |
# | n_updates          | 74       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 9472     |
# | time_elapsed       | 12       |
# | total_timesteps    | 9472     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 752      |
# | n_updates          | 75       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 9600     |
# | time_elapsed       | 12.2     |
# | total_timesteps    | 9600     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 763      |
# | n_updates          | 76       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 9728     |
# | time_elapsed       | 12.4     |
# | total_timesteps    | 9728     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 762      |
# | n_updates          | 77       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 9856     |
# | time_elapsed       | 12.6     |
# | total_timesteps    | 9856     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 745      |
# | n_updates          | 78       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 9984     |
# | time_elapsed       | 12.7     |
# | total_timesteps    | 9984     |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 744      |
# | n_updates          | 79       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 10112    |
# | time_elapsed       | 12.9     |
# | total_timesteps    | 10112    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 742      |
# | n_updates          | 80       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 10240    |
# | time_elapsed       | 13.1     |
# | total_timesteps    | 10240    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 736      |
# | n_updates          | 81       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 10368    |
# | time_elapsed       | 13.2     |
# | total_timesteps    | 10368    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 491      |
# | n_updates          | 82       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 10496    |
# | time_elapsed       | 13.4     |
# | total_timesteps    | 10496    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 726      |
# | n_updates          | 83       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 10624    |
# | time_elapsed       | 13.7     |
# | total_timesteps    | 10624    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 734      |
# | n_updates          | 84       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 10752    |
# | time_elapsed       | 13.9     |
# | total_timesteps    | 10752    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 738      |
# | n_updates          | 85       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 10880    |
# | time_elapsed       | 14       |
# | total_timesteps    | 10880    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 701      |
# | n_updates          | 86       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 11008    |
# | time_elapsed       | 14.2     |
# | total_timesteps    | 11008    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 510      |
# | n_updates          | 87       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 11136    |
# | time_elapsed       | 14.4     |
# | total_timesteps    | 11136    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 688      |
# | n_updates          | 88       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 11264    |
# | time_elapsed       | 14.6     |
# | total_timesteps    | 11264    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 723      |
# | n_updates          | 89       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 11392    |
# | time_elapsed       | 14.8     |
# | total_timesteps    | 11392    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 722      |
# | n_updates          | 90       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 11520    |
# | time_elapsed       | 15       |
# | total_timesteps    | 11520    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 704      |
# | n_updates          | 91       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 11648    |
# | time_elapsed       | 15.2     |
# | total_timesteps    | 11648    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 663      |
# | n_updates          | 92       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 11776    |
# | time_elapsed       | 15.4     |
# | total_timesteps    | 11776    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 684      |
# | n_updates          | 93       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 11904    |
# | time_elapsed       | 15.6     |
# | total_timesteps    | 11904    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 680      |
# | n_updates          | 94       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 12032    |
# | time_elapsed       | 15.8     |
# | total_timesteps    | 12032    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 717      |
# | n_updates          | 95       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 12160    |
# | time_elapsed       | 15.9     |
# | total_timesteps    | 12160    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 709      |
# | n_updates          | 96       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 12288    |
# | time_elapsed       | 16.1     |
# | total_timesteps    | 12288    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 703      |
# | n_updates          | 97       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 12416    |
# | time_elapsed       | 16.3     |
# | total_timesteps    | 12416    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 609      |
# | n_updates          | 98       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 12544    |
# | time_elapsed       | 16.5     |
# | total_timesteps    | 12544    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 541      |
# | n_updates          | 99       |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 12672    |
# | time_elapsed       | 16.7     |
# | total_timesteps    | 12672    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 646      |
# | n_updates          | 100      |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 12800    |
# | time_elapsed       | 16.9     |
# | total_timesteps    | 12800    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 676      |
# | n_updates          | 101      |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 12928    |
# | time_elapsed       | 17.1     |
# | total_timesteps    | 12928    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 665      |
# | n_updates          | 102      |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 13056    |
# | time_elapsed       | 17.3     |
# | total_timesteps    | 13056    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 684      |
# | n_updates          | 103      |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 13184    |
# | time_elapsed       | 17.5     |
# | total_timesteps    | 13184    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 689      |
# | n_updates          | 104      |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 13312    |
# | time_elapsed       | 17.7     |
# | total_timesteps    | 13312    |
# | value_loss         | nan      |
# ---------------------------------
# ...
# | time_elapsed       | 39.8     |
# | total_timesteps    | 25856    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 472      |
# | n_updates          | 203      |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 25984    |
# | time_elapsed       | 40.2     |
# | total_timesteps    | 25984    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 490      |
# | n_updates          | 204      |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 26112    |
# | time_elapsed       | 40.4     |
# | total_timesteps    | 26112    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 499      |
# | n_updates          | 205      |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 26240    |
# | time_elapsed       | 40.7     |
# | total_timesteps    | 26240    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 482      |
# | n_updates          | 206      |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 26368    |
# | time_elapsed       | 41       |
# | total_timesteps    | 26368    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 483      |
# | n_updates          | 207      |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 26496    |
# | time_elapsed       | 41.2     |
# | total_timesteps    | 26496    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 488      |
# | n_updates          | 208      |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 26624    |
# | time_elapsed       | 41.5     |
# | total_timesteps    | 26624    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 508      |
# | n_updates          | 209      |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 26752    |
# | time_elapsed       | 41.8     |
# | total_timesteps    | 26752    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 481      |
# | n_updates          | 210      |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 26880    |
# | time_elapsed       | 42       |
# | total_timesteps    | 26880    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 478      |
# | n_updates          | 211      |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 27008    |
# | time_elapsed       | 42.3     |
# | total_timesteps    | 27008    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 482      |
# | n_updates          | 212      |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 27136    |
# | time_elapsed       | 42.5     |
# | total_timesteps    | 27136    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 499      |
# | n_updates          | 213      |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 27264    |
# | time_elapsed       | 42.8     |
# | total_timesteps    | 27264    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 472      |
# | n_updates          | 214      |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 27392    |
# | time_elapsed       | 43.1     |
# | total_timesteps    | 27392    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 473      |
# | n_updates          | 215      |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 27520    |
# | time_elapsed       | 43.3     |
# | total_timesteps    | 27520    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 463      |
# | n_updates          | 216      |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 27648    |
# | time_elapsed       | 43.6     |
# | total_timesteps    | 27648    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 466      |
# | n_updates          | 217      |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 27776    |
# | time_elapsed       | 43.9     |
# | total_timesteps    | 27776    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 469      |
# | n_updates          | 218      |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 27904    |
# | time_elapsed       | 44.2     |
# | total_timesteps    | 27904    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 464      |
# | n_updates          | 219      |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 28032    |
# | time_elapsed       | 44.4     |
# | total_timesteps    | 28032    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 471      |
# | n_updates          | 220      |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 28160    |
# | time_elapsed       | 44.7     |
# | total_timesteps    | 28160    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 463      |
# | n_updates          | 221      |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 28288    |
# | time_elapsed       | 45       |
# | total_timesteps    | 28288    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 451      |
# | n_updates          | 222      |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 28416    |
# | time_elapsed       | 45.3     |
# | total_timesteps    | 28416    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 467      |
# | n_updates          | 223      |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 28544    |
# | time_elapsed       | 45.5     |
# | total_timesteps    | 28544    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 460      |
# | n_updates          | 224      |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 28672    |
# | time_elapsed       | 45.8     |
# | total_timesteps    | 28672    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 458      |
# | n_updates          | 225      |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 28800    |
# | time_elapsed       | 46.1     |
# | total_timesteps    | 28800    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 475      |
# | n_updates          | 226      |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 28928    |
# | time_elapsed       | 46.4     |
# | total_timesteps    | 28928    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------
# | approxkl           | nan      |
# | clipfrac           | 0.0      |
# | explained_variance | nan      |
# | fps                | 462      |
# | n_updates          | 227      |
# | policy_entropy     | nan      |
# | policy_loss        | nan      |
# | serial_timesteps   | 29056    |
# | time_elapsed       | 46.7     |
# | total_timesteps    | 29056    |
# | value_loss         | nan      |
# ---------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-a0f66416e5af> in <module>
#      23              verbose=1,
#      24              tensorboard_log="./tensorboard/")
# ---> 25 model.learn(total_timesteps=50000)
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps)
#     334                 callback.on_rollout_start()
#     335                 # true_reward is the reward without discount
# --> 336                 rollout = self.runner.run(callback)
#     337                 # Unpack
#     338                 obs, returns, masks, actions, values, neglogpacs, states, ep_infos, true_reward = rollout
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/stable_baselines/common/runners.py in run(self, callback)
#      46         self.callback = callback
#      47         self.continue_training = True
# ---> 48         return self._run()
#      49
#      50     @abstractmethod
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py in _run(self)
#     480             if isinstance(self.env.action_space, gym.spaces.Box):
#     481                 clipped_actions = np.clip(actions, self.env.action_space.low, self.env.action_space.high)
# --> 482             self.obs[:], rewards, self.dones, infos = self.env.step(clipped_actions)
#     483
#     484             self.model.num_timesteps += self.n_envs
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/stable_baselines/common/vec_env/base_vec_env.py in step(self, actions)
#     148         """
#     149         self.step_async(actions)
# --> 150         return self.step_wait()
#     151
#     152     def get_images(self) -> Sequence[np.ndarray]:
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/stable_baselines/common/vec_env/dummy_vec_env.py in step_wait(self)
#      42         for env_idx in range(self.num_envs):
#      43             obs, self.buf_rews[env_idx], self.buf_dones[env_idx], self.buf_infos[env_idx] =\
# ---> 44                 self.envs[env_idx].step(self.actions[env_idx])
#      45             if self.buf_dones[env_idx]:
#      46                 # save final observation where user can get it, then reset
#
# <ipython-input-51-ba58ecade049> in step(self, action)
#      70             self.btc_held = 0
#      71             self._reset_session()
# ---> 72         obs = self._next_observation()
#      73         reward = self.net_worth
#      74         done = self.net_worth <= 0
#
# <ipython-input-51-ba58ecade049> in _next_observation(self)
#      55             self.active_df['Volume'].values[self.current_step:end],
#      56         ])
# ---> 57         scaled_history = self.scaler.fit_transform(self.account_history)
#      58         obs = np.append(obs, scaled_history[:, -(self.lookback_window_size + 1):], axis=0)
#      59         return obs
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/sklearn/preprocessing/_data.py in fit(self, X, y)
#     361         # Reset internal state before fitting
#     362         self._reset()
# --> 363         return self.partial_fit(X, y)
#     364
#     365     def partial_fit(self, X, y=None):
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/sklearn/preprocessing/_data.py in partial_fit(self, X, y)
#     398                                 force_all_finite="allow-nan")
#     399
# --> 400         data_min = np.nanmin(X, axis=0)
#     401         data_max = np.nanmax(X, axis=0)
#     402
#
# <__array_function__ internals> in nanmin(*args, **kwargs)
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/numpy/lib/nanfunctions.py in nanmin(a, axis, out, keepdims)
#     318         # which do not implement isnan (gh-9009), or fmin correctly (gh-8975)
#     319         res = np.fmin.reduce(a, axis=axis, out=out, **kwargs)
# --> 320         if np.isnan(res).any():
#     321             warnings.warn("All-NaN slice encountered", RuntimeWarning,
#     322                           stacklevel=3)
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/numpy/core/_methods.py in _any(a, axis, dtype, out, keepdims, where)
#      54     # Parsing keyword arguments is currently fairly slow, so avoid it for now
#      55     if where is True:
# ---> 56         return umr_any(a, axis, dtype, out, keepdims)
#      57     return umr_any(a, axis, dtype, out, keepdims, where=where)
#      58
#
# KeyboardInterrupt:

# %%
class BitcoinTradingEnv(gym.Env):
    """A Bitcoin trading environment for OpenAI gym"""
    metadata = {'render.modes': ['live', 'file', 'none']}
    scaler = preprocessing.MinMaxScaler()
    viewer = None
    
    
    
    def __init__(self, df, lookback_window_size=50, commission=0.00075,  initial_balance=10000, serial=False):
        super(BitcoinTradingEnv, self).__init__()
        self.df = df.dropna().reset_index()
        self.lookback_window_size = lookback_window_size
        self.initial_balance = initial_balance
        self.commission = commission
        self.serial = serial
        # Actions of the format Buy 1/10, Sell 3/10, Hold, etc.
        self.action_space = spaces.MultiDiscrete([3, 10])
        # Observes the OHCLV values, net worth, and trade history
        self.observation_space = spaces.Box(low=0, high=1, shape=(10, 
                    lookback_window_size + 1), dtype=np.float16)
        self.MAX_TRADING_SESSION = 1000  # ~2 months
        
    def reset(self):
        self.balance = self.initial_balance
        self.net_worth = self.initial_balance
        self.btc_held = 0
        self._reset_session()
        self.account_history = np.repeat([
        [self.net_worth],
        [0],
        [0],
        [0],
        [0]
        ], self.lookback_window_size + 1, axis=1)
        self.trades = []
        return self._next_observation()
    
    def _reset_session(self):
        self.current_step = 0
        if self.serial:
            self.steps_left = len(self.df) - self.lookback_window_size - 1
            self.frame_start = self.lookback_window_size
        else:
            self.steps_left = np.random.randint(1, self.MAX_TRADING_SESSION)
            self.frame_start = np.random.randint(self.lookback_window_size, len(self.df) - self.steps_left)
            self.active_df = self.df[self.frame_start -   self.lookback_window_size:self.frame_start + self.steps_left]
    
    def _next_observation(self):
        end = self.current_step + self.lookback_window_size + 1
        obs = np.array([
            self.active_df['Open'].values[self.current_step:end],  
            self.active_df['High'].values[self.current_step:end],
            self.active_df['Low'].values[self.current_step:end],
            self.active_df['Close'].values[self.current_step:end],
            self.active_df['Volume'].values[self.current_step:end],
        ])
        scaled_history = self.scaler.fit_transform(self.account_history)
        obs = np.append(obs, scaled_history[:, -(self.lookback_window_size + 1):], axis=0)
        return obs
    
    def step(self, action):
        current_price = np.random.uniform(
            self.df.loc[self.current_step, "Open"], self.df.loc[self.current_step, "Close"])
        #current_price = self._get_current_price() + 0.01
        self._take_action(action, current_price)
        self.steps_left -= 1
        self.current_step += 1
        if self.steps_left == 0:
            self.balance += self.btc_held * current_price
            self.btc_held = 0
            self._reset_session()
        obs = self._next_observation()
        reward = self.net_worth
        done = self.net_worth <= 0
        return obs, reward, done, {}
    
    def _take_action(self, action, current_price):
        action_type = action[0]
        amount = action[1] / 10
        btc_bought = 0
        btc_sold = 0
        cost = 0
        sales = 0
        if action_type < 1:
            btc_bought = self.balance / current_price * amount
            cost = btc_bought * current_price * (1 + self.commission)
            self.btc_held += btc_bought
            self.balance -= cost
        elif action_type < 2:
            btc_sold = self.btc_held * amount
            sales = btc_sold * current_price  * (1 - self.commission)
            self.btc_held -= btc_sold
            self.balance += sales

        if btc_sold > 0 or btc_bought > 0:
            self.trades.append({
              'step': self.frame_start+self.current_step,
              'amount': btc_sold if btc_sold > 0 else btc_bought,
              'total': sales if btc_sold > 0 else cost,
              'type': "sell" if btc_sold > 0 else "buy"
            })
        self.net_worth = self.balance + self.btc_held * current_price
        self.account_history = np.append(self.account_history, [
            [self.net_worth],
            [btc_bought],
            [cost],
            [btc_sold],
            [sales]
            ], axis=1)
        
    def render(self, mode='human', **kwargs):
        if mode == 'human':
            if self.viewer == None:
                self.viewer = BitcoinTradingGraph(self.df,kwargs.get('title', None))
            self.viewer.render(self.frame_start + self.current_step,
                           self.net_worth,
                           self.trades,
                           window_size=self.lookback_window_size)
